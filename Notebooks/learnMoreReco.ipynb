# %% [markdown]
# The goal of this notebook is to make functions to make recommendations for the data we scraped and then choose the function that makes the best recommendations

# %%
import pandas as pd

# %%
sim = pd.read_csv('../data_for_notebooks/internshala_recommendation_matrix.csv') 
sim_1 = pd.read_csv('../data_for_notebooks/internshala_recommendation_matrix_wo_tfidf.csv')
sim_2 = pd.read_csv('../data_for_notebooks/internshala_recommendation_matrix_w_lem.csv')
sim_3 = pd.read_csv('../data_for_notebooks/internshala_recommendation_matrix_w_lem_wo_tfidf.csv')
df = pd.read_csv('../data_for_notebooks/internshala_dataset.csv')
sim_cat = pd.read_csv('../data_for_notebooks/internshala_recommendation_df_cat.csv')

# %% [markdown]
# Thus we have the following dataframes loaded:
#
# **sim** : similarity matrix with stemming and tfidf
#
# **sim_1** : similarity matrix made without using tfidf but with stemming
#
# **sim_2** : similarity matrix made with lemmatizing and tfidf
#
# **sim_3** : similarity matrix made with lemmatization and without tfidf
#
# **sim_cat** : similarity matrix made using category column and with stemming but without tfidf
#
# **df** : dataframe with all the internships

# %%
df.insert(0, 'id', range(0, 0 + len(df)))
df
# Out:
#       id                            Title  \
# 0      0                Sales & Marketing
# 1      1     Business Development (Sales)
# 2      2  Teaching (Computer Programming)
# 3      3                Baking - Culinary
# 4      4                  Web Development
# ..   ...                              ...
# 457  457             Human Resources (HR)
# 458  458     Business Development (Sales)
# 459  459                Campus Management
# 460  460              Regional Management
# 461  461           Campus Lead Management
#
#                                    Company        Location  Duration  \
# 0    Decathlon Sport India Private Limited         Chennai  3 Months
# 1                     Aditya Birla Capital         Kolkata  3 Months
# 2                                 Nimble-Q    Kanpur Dehat  3 Months
# 3                        Prianka Khushwani           Delhi  6 Months
# 4                    Spring 360 Technology          Bhopal  3 Months
# ..                                     ...             ...       ...
# 457             Graygraph Technologies LLC       Ghaziabad  2 Months
# 458                       Synergies Ananta         Jodhpur  2 Months
# 459                                  Ulead  Work From Home   1 Month
# 460                                  Ulead  Work From Home   1 Month
# 461                                  Ulead  Work From Home   1 Month
#
#                Stipend    Apply By             Applicants  \
# 0         10000 /month  19 Apr' 22  Be an early applicant
# 1     2000-3000 /month  16 Apr' 22          52 applicants
# 2           1600 /week  24 Apr' 22  Be an early applicant
# 3          4000 /month  24 Apr' 22  Be an early applicant
# 4    7000-20000 /month  24 Apr' 22  Be an early applicant
# ..                 ...         ...                    ...
# 457       10000 /month  12 Apr' 22         129 applicants
# 458   4000-9000 /month  15 Apr' 22  Be an early applicant
# 459        2000 /month  15 Apr' 22       1000+ applicants
# 460        2000 /month  15 Apr' 22       1000+ applicants
# 461        2000 /month  13 Apr' 22         529 applicants
#
#                                        Skills Required  \
# 0                                                  NaN
# 1                                                  NaN
# 2                           Android , Java , Python ,
# 3                                     Culinary Arts ,
# 4    .NET , JavaScript , Node.js , PHP , Python , R...
# ..                                                 ...
# 457                                                NaN
# 458                                                NaN
# 459  English Proficiency (Spoken) , English Profici...
# 460  English Proficiency (Spoken) , English Profici...
# 461  English Proficiency (Spoken) , English Profici...
#
#                                                  Perks  Number of Openings  \
# 0    Certificate , Letter of recommendation , Flexi...                   4
# 1    Certificate , Letter of recommendation , Job o...                  20
# 2    Certificate , Letter of recommendation , Job o...                   1
# 3    Certificate , Letter of recommendation , Flexi...                   2
# 4    Certificate , Letter of recommendation , Flexi...                   8
# ..                                                 ...                 ...
# 457  Certificate , Letter of recommendation , Flexi...                   5
# 458  Certificate , Letter of recommendation , Flexi...                  10
# 459  Certificate , Letter of recommendation , Flexi...                  10
# 460  Certificate , Letter of recommendation , Flexi...                  15
# 461  Certificate , Letter of recommendation , Flexi...                  15
#
#                                                   Link
# 0    https://internshala.com/internship/detail/sale...
# 1    https://internshala.com/internship/detail/busi...
# 2    https://internshala.com/internship/detail/teac...
# 3    https://internshala.com/internship/detail/baki...
# 4    https://internshala.com/internship/detail/web-...
# ..                                                 ...
# 457  https://internshala.com/internship/detail/huma...
# 458  https://internshala.com/internship/detail/busi...
# 459  https://internshala.com/internship/detail/camp...
# 460  https://internshala.com/internship/detail/regi...
# 461  https://internshala.com/internship/detail/camp...
#
# [462 rows x 12 columns]

# %%
# setting id column as index
sim.set_index('id', inplace = True)
sim_1.set_index('id', inplace = True)
sim_2.set_index('id', inplace = True)
sim_3.set_index('id', inplace = True)
sim_cat.set_index('id', inplace = True)

# %% [markdown]
# Making the recommendation function:

# %%
def make_recs(sim, df, i, n):
    '''
    returns a dataframe of top n recommendations, based on the similarity matrix provided and dataframe 
    provided, for a user who viewed the internship with the ith ID.
    
    INPUT:
    sim - similarity matrix(dataframe)
    df - original dataframe with all the data
    i - id of the internship that was viewed by the user
    n - top n recommendations to be made to the user 
    
    OUTPUT:
    recs_df - dataframe consisting of the recommended internships
    
    '''
    ith_series = sim.loc[:,str(i)]
    ith_series = ith_series.sort_values(ascending = False)
    # print(ith_series)
    recs = ith_series.head(n+1).index.tolist()
    
    # what might happen is that multiple elements attain maximum similarity value. Then it is possible that 
    # we don't get i in our recs. so for that the below is done. 
    if i in recs: 
        recs.remove(i)
    else:
        recs = recs[:-1]
        
    # below ensures that the order of the recommendations is as in recs cause otherwise the use of .isin
    # reorders recs in the way they appear in df, i.e, in ascending order
    recs_df = df[df.id.isin(recs)].set_index('id').T[recs].T.reset_index()
    
    return recs_df

# %% [markdown]
# Running an example below for all the similarity matrices :

# %%
# original internship viewed by the user
df[df.id == 110]
# Out:
#       id                      Title Company        Location Duration  \
# 110  110  Technical Content Writing    Sarg  Work From Home  1 Month
#
#                Stipend    Apply By      Applicants  \
# 110  7000-10000 /month  20 Apr' 22  109 applicants
#
#                                        Skills Required  \
# 110  Copywriting , Creative Writing , Digital Marke...
#
#                                                  Perks  Number of Openings  \
# 110  Certificate , Letter of recommendation , Flexi...                   4
#
#                                                   Link
# 110  https://internshala.com/internship/detail/tech...

# %% [markdown]
# ### Recommended internships using different dataframes :

# %% [markdown]
# ### for sim :

# %%
make_recs(sim, df, 110, 3)
# Out:
#     id                        Title                   Company        Location  \
# 0  128    Technical Content Writing  Snowball Innovation Labs  Work From Home
# 1  433             Content Creation                     Edten          Jaipur
# 2  332  Subject Matter Expert (SME)               PearlySight            Pune
#
#    Duration             Stipend    Apply By             Applicants  \
# 0   1 Month   7000-10000 /month  19 Apr' 22         114 applicants
# 1  3 Months    2500-5500 /month  13 Apr' 22         123 applicants
# 2  3 Months  15000-25000 /month  13 Apr' 22  Be an early applicant
#
#                                      Skills Required  \
# 0  Copywriting , Creative Writing , Digital Marke...
# 1  Creative Writing , English Proficiency (Spoken...
# 2  English Proficiency (Written) , Social Media M...
#
#                                                Perks Number of Openings  \
# 0  Certificate , Letter of recommendation , Flexi...                  4
# 1  Certificate , Letter of recommendation , Flexi...                  4
# 2  Certificate , Letter of recommendation , Flexi...                 20
#
#                                                 Link
# 0  https://internshala.com/internship/detail/tech...
# 1  https://internshala.com/internship/detail/cont...
# 2  https://internshala.com/internship/detail/subj...

# %% [markdown]
# ### for sim_2 :

# %%
make_recs(sim_2, df, 110, 3)
# Out:
#     id                        Title                   Company        Location  \
# 0  128    Technical Content Writing  Snowball Innovation Labs  Work From Home
# 1  433             Content Creation                     Edten          Jaipur
# 2  332  Subject Matter Expert (SME)               PearlySight            Pune
#
#    Duration             Stipend    Apply By             Applicants  \
# 0   1 Month   7000-10000 /month  19 Apr' 22         114 applicants
# 1  3 Months    2500-5500 /month  13 Apr' 22         123 applicants
# 2  3 Months  15000-25000 /month  13 Apr' 22  Be an early applicant
#
#                                      Skills Required  \
# 0  Copywriting , Creative Writing , Digital Marke...
# 1  Creative Writing , English Proficiency (Spoken...
# 2  English Proficiency (Written) , Social Media M...
#
#                                                Perks Number of Openings  \
# 0  Certificate , Letter of recommendation , Flexi...                  4
# 1  Certificate , Letter of recommendation , Flexi...                  4
# 2  Certificate , Letter of recommendation , Flexi...                 20
#
#                                                 Link
# 0  https://internshala.com/internship/detail/tech...
# 1  https://internshala.com/internship/detail/cont...
# 2  https://internshala.com/internship/detail/subj...

# %% [markdown]
# ###  for sim_3 :

# %%
make_recs(sim_3, df, 110,3)
# Out:
#     id                               Title                  Company  \
# 0   91        Marketing And Communications  Sixth Degree Consulting
# 1  253  International Business Development           Matrix Exports
# 2  118                     Lead Generation               FreshNames
#
#          Location  Duration            Stipend    Apply By  \
# 0       Bangalore  2 Months        5000 /month  20 Apr' 22
# 1         Chennai  6 Months  5000-10000 /month  16 Apr' 22
# 2  Work From Home  3 Months        3000 /month  20 Apr' 22
#
#               Applicants                                    Skills Required  \
# 0  Be an early applicant  Creative Writing , English Proficiency (Spoken...
# 1          30 applicants  Digital Marketing , Email Marketing , English ...
# 2  Be an early applicant  Digital Marketing , Email Marketing , English ...
#
#                                                Perks Number of Openings  \
# 0  Certificate , Letter of recommendation , Flexi...                  3
# 1  Certificate , Letter of recommendation , Flexi...                 20
# 2  Certificate , Letter of recommendation , Flexi...                  4
#
#                                                 Link
# 0  https://internshala.com/internship/detail/mark...
# 1  https://internshala.com/internship/detail/inte...
# 2  https://internshala.com/internship/detail/lead...

# %% [markdown]
# ### for sim_cat :

# %%
make_recs(sim_cat, df, 110, 3)
# Out:
#     id                      Title                           Company  \
# 0  128  Technical Content Writing          Snowball Innovation Labs
# 1  212            Content Writing                      The Blue Owl
# 2  355            Content Writing  Veefin Solutions Private Limited
#
#          Location  Duration            Stipend    Apply By      Applicants  \
# 0  Work From Home   1 Month  7000-10000 /month  19 Apr' 22  114 applicants
# 1  Work From Home  3 Months   2500-5000 /month  18 Apr' 22   72 applicants
# 2  Work From Home  3 Months       10000 /month  13 Apr' 22   30 applicants
#
#                                      Skills Required  \
# 0  Copywriting , Creative Writing , Digital Marke...
# 1  Blogging , Creative Writing , English Proficie...
# 2  Blogging , Creative Writing , English Proficie...
#
#                                                Perks Number of Openings  \
# 0  Certificate , Letter of recommendation , Flexi...                  4
# 1  Certificate , Letter of recommendation , Flexi...                  2
# 2  Certificate , Letter of recommendation , Flexi...                  1
#
#                                                 Link
# 0  https://internshala.com/internship/detail/tech...
# 1  https://internshala.com/internship/detail/cont...
# 2  https://internshala.com/internship/detail/cont...

# %% [markdown]
# Now after a lot of mixing and matching and trying out for different ids, we came upon the decision to take a weighted sum of sim_cat and sim_1 where sim_cat will be as it is and sim_1 will be multiplied by 0.3. we do this because the weighted sum gives us a really good mix of good and relevant recommendations with seredipitous recommendations. A lot of recommendations by sim_1 are a little offbeat and help us in keeping the recommendations fresh and the users interest intact. The decision of taking the weights as 1 and 0.3 have come from experimentation and by looking at the values of sim_1 and sim_cat(sim_1 has the largest value of 520 whereas sim_cat has 5).
#
# We have done this as recommendation systems are a mix of science and art and this was the art portion where there was no exact way to determine which recommendation system was performing the best.

# %%
def combine_make_recs(df, i, n):
    '''
    takes the weighted sum of 2 similarity matrices: sim_cat and sim_1. Returns recommendations using the 
    summed up matrix.
    
    INPUT:
    df - original dataframe with all the data
    i - id of the internship that was viewed by the user
    n - top n recommendations to be made to the user 
    
    OUTPUT:
    recs_df - dataframe consisting of the recommended internships
    
    '''
    sim_combined = 0.3*sim_1 + sim_cat
    recs_df = make_recs(sim_combined, df, i, n)
    return recs_df

# %%
combine_make_recs(df, 110, 3)
# Out:
#     id                               Title                   Company  \
# 0  128           Technical Content Writing  Snowball Innovation Labs
# 1   91        Marketing And Communications   Sixth Degree Consulting
# 2  253  International Business Development            Matrix Exports
#
#          Location  Duration            Stipend    Apply By  \
# 0  Work From Home   1 Month  7000-10000 /month  19 Apr' 22
# 1       Bangalore  2 Months        5000 /month  20 Apr' 22
# 2         Chennai  6 Months  5000-10000 /month  16 Apr' 22
#
#               Applicants                                    Skills Required  \
# 0         114 applicants  Copywriting , Creative Writing , Digital Marke...
# 1  Be an early applicant  Creative Writing , English Proficiency (Spoken...
# 2          30 applicants  Digital Marketing , Email Marketing , English ...
#
#                                                Perks Number of Openings  \
# 0  Certificate , Letter of recommendation , Flexi...                  4
# 1  Certificate , Letter of recommendation , Flexi...                  3
# 2  Certificate , Letter of recommendation , Flexi...                 20
#
#                                                 Link
# 0  https://internshala.com/internship/detail/tech...
# 1  https://internshala.com/internship/detail/mark...
# 2  https://internshala.com/internship/detail/inte...
