# %%
# downloading resources and importing libraries
import nltk
nltk.download('punkt')
nltk.download('wordnet')

import pandas as pd
import numpy as np

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
import re
# Out:
# [nltk_data] Downloading package punkt to C:\Users\pansa.DESKTOP-2QTDA2
# [nltk_data]     J\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\pansa.DESKTOP-2QTD
# [nltk_data]     A2J\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('../internshala_dataset.csv')

# %%
# checking the data once
df.isnull().sum()
# Out:
# Title                  0
# Company                0
# Location               0
# Duration               0
# Stipend                0
# Apply By               0
# Applicants             0
# Skills Required       68
# Perks                  0
# Number of Openings     0
# Link                   0
# dtype: int64

# %%
df['Skills Required']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                             Android , Java , Python ,
# 3                                       Culinary Arts ,
# 4      .NET , JavaScript , Node.js , PHP , Python , R...
#                              ...
# 457                                                  NaN
# 458                                                  NaN
# 459    English Proficiency (Spoken) , English Profici...
# 460    English Proficiency (Spoken) , English Profici...
# 461    English Proficiency (Spoken) , English Profici...
# Name: Skills Required, Length: 462, dtype: object

# %%
df[df['Skills Required'].isnull()]
# Out:
#                             Title                                Company  \
# 0               Sales & Marketing  Decathlon Sport India Private Limited
# 1    Business Development (Sales)                   Aditya Birla Capital
# 11              Digital Marketing                           CreativeHigh
# 13              Digital Marketing                                 Weboin
# 17                      Marketing                    Mazatron Enterprise
# ..                            ...                                    ...
# 427          Human Resources (HR)                  Square Select Estates
# 444             Digital Marketing                       Difam (Stallion)
# 453           Personal Assistance                         MeetUniversity
# 457          Human Resources (HR)             Graygraph Technologies LLC
# 458  Business Development (Sales)                       Synergies Ananta
#
#            Location  Duration                    Stipend    Apply By  \
# 0           Chennai  3 Months               10000 /month  19 Apr' 22
# 1           Kolkata  3 Months           2000-3000 /month  16 Apr' 22
# 11   Work From Home  3 Months  2000 /month +  Incentives  23 Apr' 22
# 13          Chennai  6 Months               15000 /month  23 Apr' 22
# 17            Noida  6 Months  5000 /month +  Incentives  22 Apr' 22
# ..              ...       ...                        ...         ...
# 427       Hyderabad  6 Months                7000 /month  11 Apr' 22
# 444       Hyderabad  2 Months           3000-8000 /month  10 Apr' 22
# 453  Work From Home  6 Months                5000 /month  15 Apr' 22
# 457       Ghaziabad  2 Months               10000 /month  12 Apr' 22
# 458         Jodhpur  2 Months           4000-9000 /month  15 Apr' 22
#
#                 Applicants Skills Required  \
# 0    Be an early applicant             NaN
# 1            52 applicants             NaN
# 11           78 applicants             NaN
# 13   Be an early applicant             NaN
# 17   Be an early applicant             NaN
# ..                     ...             ...
# 427  Be an early applicant             NaN
# 444  Be an early applicant             NaN
# 453  Be an early applicant             NaN
# 457         129 applicants             NaN
# 458  Be an early applicant             NaN
#
#                                                  Perks  Number of Openings  \
# 0    Certificate , Letter of recommendation , Flexi...                   4
# 1    Certificate , Letter of recommendation , Job o...                  20
# 11   Certificate , Letter of recommendation , Flexi...                   5
# 13   Certificate , Letter of recommendation , Flexi...                  13
# 17   Certificate , Letter of recommendation , Flexi...                  20
# ..                                                 ...                 ...
# 427  Certificate , Letter of recommendation , Flexi...                   1
# 444  Certificate , Letter of recommendation , Flexi...                   4
# 453  Certificate , Letter of recommendation , Job o...                   1
# 457  Certificate , Letter of recommendation , Flexi...                   5
# 458  Certificate , Letter of recommendation , Flexi...                  10
#
#                                                   Link
# 0    https://internshala.com/internship/detail/sale...
# 1    https://internshala.com/internship/detail/busi...
# 11   https://internshala.com/internship/detail/digi...
# 13   https://internshala.com/internship/detail/digi...
# 17   https://internshala.com/internship/detail/mark...
# ..                                                 ...
# 427  https://internshala.com/internship/detail/huma...
# 444  https://internshala.com/internship/detail/digi...
# 453  https://internshala.com/internship/detail/pers...
# 457  https://internshala.com/internship/detail/huma...
# 458  https://internshala.com/internship/detail/busi...
#
# [68 rows x 11 columns]

# %%
df.at[1, 'Skills Required'] = 'Sales and Marketing'

# %%
df.loc[df['Title'] == 'Business Development (Sales)', 'Skills Required'] = 'Sales, Marketing'

# %%
# checking the data once
df.isnull().sum()
# Out:
# Title                  0
# Company                0
# Location               0
# Duration               0
# Stipend                0
# Apply By               0
# Applicants             0
# Skills Required       55
# Perks                  0
# Number of Openings     0
# Link                   0
# dtype: int64

# %%
df.loc[df['Title'] == 'Human Resources (HR)', 'Skills Required'] = 'Problem Solving, Pulic Relations'

# %%
df.loc[df['Title'] == 'Graphic Design', 'Skills Required'] = 'Creativity'

# %%
df.loc[df['Title'] == 'Digital Marketing', 'Skills Required'] = 'Digital Marketing'

# %%
df.loc[df['Title'] == 'Marketing', 'Skills Required'] = 'Marketing'

# %%
# checking the data once
df.isnull().sum()
# Out:
# Title                  0
# Company                0
# Location               0
# Duration               0
# Stipend                0
# Apply By               0
# Applicants             0
# Skills Required       33
# Perks                  0
# Number of Openings     0
# Link                   0
# dtype: int64

# %%
df[df['Skills Required'].isnull()]
# Out:
#                                     Title  \
# 0                       Sales & Marketing
# 32                   Video Making/Editing
# 33                       English Training
# 47                Electronics Engineering
# 58                 Social Media Marketing
# 63   Product Design (Bracelets & Jewelry)
# 87                        Content Writing
# 117                       Content Writing
# 123         Firmware/Hardware Engineering
# 132                    Dance Facilitation
# 135        Fundraising (Financial Growth)
# 145               Wix Website Development
# 176             Dance Fitness Instruction
# 191      Research & Development - Chemist
# 192                           Fundraising
# 216                  Education Counseling
# 222                 Qliksense Development
# 226       Subject Matter Expert (Medical)
# 235                Social Media Marketing
# 239                    Property Surveying
# 252                            Operations
# 274                     Sales & Marketing
# 296                            Data Entry
# 297                    Business Analytics
# 309                    Virtual Assistance
# 318                Social Media Marketing
# 319                Social Media Marketing
# 334                            Operations
# 338                Social Media Marketing
# 341                Social Media Marketing
# 360                       Web Development
# 393                              Coaching
# 453                   Personal Assistance
#
#                                                Company        Location  \
# 0                Decathlon Sport India Private Limited         Chennai
# 32                                    Wrig Productions            Pune
# 33                                  Zenith Consultants           Delhi
# 47                                        Griden Power       Ahmedabad
# 58                                              Weboin         Chennai
# 63                                          ForestFuse          Jaipur
# 87                            Yink OPC Private Limited  Work From Home
# 117                                    Strategic Links  Work From Home
# 123       Fourth Frontier Technologies Private Limited       Bangalore
# 132             CreateJoy Technologies Private Limited  Work From Home
# 296                  10  https://internshala.com/internship/detail/data...
# 297                   3  https://internshala.com/internship/detail/busi...
# 309                   5  https://internshala.com/internship/detail/virt...
# 318                   4  https://internshala.com/internship/detail/soci...
# 319                   4  https://internshala.com/internship/detail/soci...
# 334                   2  https://internshala.com/internship/detail/oper...
# 338                   5  https://internshala.com/internship/detail/soci...
# 341                   1  https://internshala.com/internship/detail/soci...
# 360                   3  https://internshala.com/internship/detail/web-...
# 393                   2  https://internshala.com/internship/detail/coac...
# 453                   1  https://internshala.com/internship/detail/pers...

# %%
df.loc[df['Title'] == 'Content Writing', 'Skills Required'] = 'Engish Proficiency'

# %%
df.loc[df['Title'] == 'Personal Assistance', 'Skills Required'] = 'Communication Skills'

# %%
df.loc[df['Title'] == 'Web Development', 'Skills Required'] = 'Full Stack Development'

# %%
df.loc[df['Title'] == 'Social Media Marketing', 'Skills Required'] = 'Social Media Marketing'

# %%
df.loc[df['Title'] == 'Virtual Assistance', 'Skills Required'] = 'Communication  Skills'

# %%
df.loc[df['Title'] == 'Business Analytics', 'Skills Required'] = 'Data Analysis'

# %%
df.loc[df['Title'] == 'Data Entry', 'Skills Required'] = 'Microsoft Excel'

# %%
df.loc[df['Title'] == 'Property Surveying', 'Skills Required'] = 'Communication Skills'

# %%
df.loc[df['Title'] == 'Subject Matter Expert (Medical)', 'Skills Required'] = 'Medical Expert'

# %%
df.loc[df['Title'] == 'Qliksense Development', 'Skills Required'] = 'AI'

# %%
df.loc[df['Title'] == 'Education Counseling', 'Skills Required'] = 'Counseling'

# %%
# checking the data once
df.isnull().sum()
# Out:
# Title                  0
# Company                0
# Location               0
# Duration               0
# Stipend                0
# Apply By               0
# Applicants             0
# Skills Required       16
# Perks                  0
# Number of Openings     0
# Link                   0
# dtype: int64

# %%
df["Skills Required"].fillna("Communication Skills", inplace = True)

# %%
# checking the data once
df.isnull().sum()
# Out:
# Title                 0
# Company               0
# Location              0
# Duration              0
# Stipend               0
# Apply By              0
# Applicants            0
# Skills Required       0
# Perks                 0
# Number of Openings    0
# Link                  0
# dtype: int64

# %%
# checking the shape once again
df.shape
# Out:
# (462, 11)

# %%
df['Skills Required'].str.lower()
# Out:
# 0                                   communication skills
# 1                                       sales, marketing
# 2                             android , java , python ,
# 3                                       culinary arts ,
# 4                                 full stack development
#                              ...
# 457                     problem solving, pulic relations
# 458                                     sales, marketing
# 459    english proficiency (spoken) , english profici...
# 460    english proficiency (spoken) , english profici...
# 461    english proficiency (spoken) , english profici...
# Name: Skills Required, Length: 462, dtype: object

# %%
df['Location'].str.lower()
# Out:
# 0             chennai
# 1             kolkata
# 2        kanpur dehat
# 3               delhi
# 4              bhopal
#             ...
# 457         ghaziabad
# 458           jodhpur
# 459    work from home
# 460    work from home
# 461    work from home
# Name: Location, Length: 462, dtype: object

# %%
df
# Out:
#       id                            Title  \
# 0      0                Sales & Marketing
# 1      1     Business Development (Sales)
# 2      2  Teaching (Computer Programming)
# 3      3                Baking - Culinary
# 4      4                  Web Development
# ..   ...                              ...
# 457  457             Human Resources (HR)
# 458  458     Business Development (Sales)
# 459  459                Campus Management
# 460  460              Regional Management
# 461  461           Campus Lead Management
#
#                                    Company        Location  Duration  \
# 0    Decathlon Sport India Private Limited         Chennai  3 Months
# 1                     Aditya Birla Capital         Kolkata  3 Months
# 2                                 Nimble-Q    Kanpur Dehat  3 Months
# 3                        Prianka Khushwani           Delhi  6 Months
# 4                    Spring 360 Technology          Bhopal  3 Months
# ..                                     ...             ...       ...
# 457             Graygraph Technologies LLC       Ghaziabad  2 Months
# 458                       Synergies Ananta         Jodhpur  2 Months
# 459                                  Ulead  Work From Home   1 Month
# 460                                  Ulead  Work From Home   1 Month
# 461                                  Ulead  Work From Home   1 Month
#
#                Stipend    Apply By             Applicants  \
# 0         10000 /month  19 Apr' 22  Be an early applicant
# 1     2000-3000 /month  16 Apr' 22          52 applicants
# 2           1600 /week  24 Apr' 22  Be an early applicant
# 3          4000 /month  24 Apr' 22  Be an early applicant
# 4    7000-20000 /month  24 Apr' 22  Be an early applicant
# ..                 ...         ...                    ...
# 457       10000 /month  12 Apr' 22         129 applicants
# 458   4000-9000 /month  15 Apr' 22  Be an early applicant
# 459        2000 /month  15 Apr' 22       1000+ applicants
# 460        2000 /month  15 Apr' 22       1000+ applicants
# 461        2000 /month  13 Apr' 22         529 applicants
#
#                                        Skills Required  \
# 0                                 Communication Skills
# 1                                     Sales, Marketing
# 2                           Android , Java , Python ,
# 3                                     Culinary Arts ,
# 4                               Full Stack Development
# ..                                                 ...
# 457                   Problem Solving, Pulic Relations
# 458                                   Sales, Marketing
# 459  English Proficiency (Spoken) , English Profici...
# 460  English Proficiency (Spoken) , English Profici...
# 461  English Proficiency (Spoken) , English Profici...
#
#                                                  Perks  Number of Openings  \
# 0    Certificate , Letter of recommendation , Flexi...                   4
# 1    Certificate , Letter of recommendation , Job o...                  20
# 2    Certificate , Letter of recommendation , Job o...                   1
# 3    Certificate , Letter of recommendation , Flexi...                   2
# 4    Certificate , Letter of recommendation , Flexi...                   8
# ..                                                 ...                 ...
# 457  Certificate , Letter of recommendation , Flexi...                   5
# 458  Certificate , Letter of recommendation , Flexi...                  10
# 459  Certificate , Letter of recommendation , Flexi...                  10
# 460  Certificate , Letter of recommendation , Flexi...                  15
# 461  Certificate , Letter of recommendation , Flexi...                  15
#
#                                                   Link
# 0    https://internshala.com/internship/detail/sale...
# 1    https://internshala.com/internship/detail/busi...
# 2    https://internshala.com/internship/detail/teac...
# 3    https://internshala.com/internship/detail/baki...
# 4    https://internshala.com/internship/detail/web-...
# ..                                                 ...
# 457  https://internshala.com/internship/detail/huma...
# 458  https://internshala.com/internship/detail/busi...
# 459  https://internshala.com/internship/detail/camp...
# 460  https://internshala.com/internship/detail/regi...
# 461  https://internshala.com/internship/detail/camp...
#
# [462 rows x 12 columns]

# %% [markdown]
# We have decided to use the following features for creating filters in the app:
#
# 1. Skills Required
# 2. Location
# 3. Stipend
#
# In the final app, the user will be choosing from the options provided or inputting the data themselves for these categories. Haven't decided on that part yet. Based on the profile ID they have entered, we will be using a content based recommendation system to recommend the user similar profiles. This similarity will be based on the details column.
#
# We will be creating functions to implement the following steps in this notebook :
# 1. Normalize : Remove extra signs and numbers form the sentences (everything is already lowercase)
# 2. Tokenize
# 3. Remove extra space from all tokens
# 4. Stem each token

# %%
def tokenize(sentences):
    '''
    tokenizes a bunch of sentences after normalizing them and returns stemmed tokens.
    
    INPUT:
    sentences - a paragraph that need to be tokenized
    
    OUTPUT:
    tokens - list of stemmed tokens
    
    '''
    # normalizing, tokenizing, lemmatizing 
    sentences = re.sub('\W',' ',sentences) 
    sentences = re.sub('[0-9]',' ',sentences)

    tokens = word_tokenize(sentences)
    tokens = [i.strip() for i in tokens]
    
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(i) for i in tokens]
    return tokens

# %%
def similarity_matrix(df):
    '''
    returns a similarity matrix, in the form of a dataframe, between different internships by using the 
    details section of df.
    
    INPUT:
    df - dataframe with 'details' as one of the columns
    
    OUTPUT:
    sim - similarity matrix(dataframe) with internship id as column and row labels 
    
    '''
    details = df['Skills Required']
    vect = CountVectorizer(tokenizer= tokenize, stop_words = 'english')
    tfidf = TfidfTransformer()
    
    mat = tfidf.fit_transform(vect.fit_transform(details).toarray()).toarray()
    sim = np.dot(mat, mat.T)
    sim = pd.DataFrame(sim, columns=df.id, index = df.id)
    return sim

# %%
sim = similarity_matrix(df)
# Out:
# C:\Users\pansa.DESKTOP-2QTDA2J\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'formerli', 'forti', 'ha', 'henc', 'hereaft', 'herebi', 'hi', 'howev', 'hundr', 'inde', 'latterli', 'mani', 'meanwhil', 'moreov', 'mostli', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'seriou', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'thi', 'thu', 'togeth', 'twelv', 'twenti', 'veri', 'wa', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(

# %%
sim.shape
# Out:
# (462, 462)

# %%
sim.to_csv('../data_for_notebooks/internshala_recommendation_matrix.csv', index = True)

# %% [markdown]
# # ***

# %% [markdown]
# After trying out the recommendations in the make_recs notebook, I have come back to this notebook to make some changes. I think that we can maybe make better recommendations and thus we will try a few things out with this data(since it isn't big at all).
#
# The few ways that I can think of right now to change how recommendations are made:
# 1. Do not use Tfidf and but stem tokens
# 2. Lemmatize the words instead of stemming them
# 3. Use lemmatization and do not use tfidf

# %% [markdown]
# 1. Do not use Tfidf

# %%
def similarity_matrix_wo_tfidf(df):
    '''
    returns a similarity matrix, in the form of a dataframe, between different internships by using the 
    details section
    
    INPUT:
    df - dataframe with 'skills required' as one of the columns
    
    OUTPUT:
    sim - similarity matrix(dataframe) with internship id as column and row labels 
    
    '''
    details = df['Skills Required']
    vect = CountVectorizer(tokenizer= tokenize, stop_words = 'english')
    
    mat = vect.fit_transform(details).toarray()
    sim = np.dot(mat, mat.T)
    sim = pd.DataFrame(sim, columns=df.id, index = df.id)
    return sim

# %%
sim_1 = similarity_matrix_wo_tfidf(df)
sim_1.to_csv('../data_for_notebooks/internshala_recommendation_matrix_wo_tfidf.csv', index = True)
# Out:
# C:\Users\pansa.DESKTOP-2QTDA2J\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'formerli', 'forti', 'ha', 'henc', 'hereaft', 'herebi', 'hi', 'howev', 'hundr', 'inde', 'latterli', 'mani', 'meanwhil', 'moreov', 'mostli', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'seriou', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'thi', 'thu', 'togeth', 'twelv', 'twenti', 'veri', 'wa', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(

# %% [markdown]
# 2. Lemmatize the word

# %%
def tokenize_lem(sentences):
    '''
    tokenizes a bunch of sentences after normalizing it and returns lemmatized tokens.
    
    INPUT:
    sentences - a paragraph that needs to be tokenized
    
    OUTPUT:
    tokens - list of lemmatized tokens
    
    '''
    # normalizing, tokenizing, lemmatizing 
    sentences = re.sub('\W',' ',sentences) 
    sentences = re.sub('[0-9]',' ',sentences)

    tokens = word_tokenize(sentences)
    tokens = [i.strip() for i in tokens]
    
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(i) for i in tokens]
    return tokens

# %%
def similarity_matrix_w_lem(df):
    '''
    returns a similarity matrix, in the form of a dataframe, between different internships by using the 
    details section
    
    INPUT:
    df - dataframe with 'Skills Required' as one of the columns
    
    OUTPUT:
    sim - similarity matrix(dataframe) with internship id as column and row labels 
    
    '''
    details = df['Skills Required']
    vect = CountVectorizer(tokenizer= tokenize_lem, stop_words = 'english')
    tfidf = TfidfTransformer()
    
    mat = tfidf.fit_transform(vect.fit_transform(details).toarray()).toarray()
    sim = np.dot(mat, mat.T)
    sim = pd.DataFrame(sim, columns=df.id, index = df.id)
    return sim

# %%
import nltk
nltk.download('omw-1.4')
sim_2 = similarity_matrix_w_lem(df)
sim_2.to_csv('../data_for_notebooks/internshala_recommendation_matrix_w_lem.csv', index = True)
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\pansa.DESKTOP-2QTD
# [nltk_data]     A2J\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\omw-1.4.zip.
# C:\Users\pansa.DESKTOP-2QTDA2J\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   warnings.warn(

# %% [markdown]
# 3. Use lemmatization and do not use tfidf

# %%
def similarity_matrix_w_lem_wo_tfidf(df):
    '''
    returns a similarity matrix, in the form of a dataframe, between different internships by using the 
    details section
    
    INPUT:
    df - dataframe with 'Skills Required' as one of the columns
    
    OUTPUT:
    sim - similarity matrix(dataframe) with internship id as column and row labels 
    '''
    details = df['Skills Required']
    vect = CountVectorizer(tokenizer= tokenize_lem, stop_words = 'english')
    tfidf = TfidfTransformer()
    
    mat = vect.fit_transform(details).toarray()
    sim = np.dot(mat, mat.T)
    sim = pd.DataFrame(sim, columns=df.id, index = df.id)
    return sim

# %%
sim_3 = similarity_matrix_w_lem_wo_tfidf(df)
sim_3.to_csv('../data_for_notebooks/internshala_recommendation_matrix_w_lem_wo_tfidf.csv', index = True)
# Out:
# C:\Users\pansa.DESKTOP-2QTDA2J\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   warnings.warn(

# %% [markdown]
# After forming these 3 with the details section, we try an alternate approach and try to use the 'category' column to form the similarity matrix. This should give us more relevant results as there are a high no. of common categories and similar internships have really similar category names. Thus, in the make_recs notebook, we will try using this too and compare it with the results of the above 3.

# %%
def similarity_matrix_cat(df):
    '''
    returns a similarity matrix, in the form of a dataframe, between different internships by using the 
    cat section
    
    INPUT:
    df - dataframe with 'Title' as one of the columns
    
    OUTPUT:
    sim - similarity matrix(dataframe) with internship id as column and row labels 
    '''
    cats = df['Title']
    vect = CountVectorizer(tokenizer= tokenize, stop_words = 'english')
    tfidf = TfidfTransformer()
    
    mat = vect.fit_transform(cats).toarray()
    sim = np.dot(mat, mat.T)
    sim = pd.DataFrame(sim, columns=df.id, index = df.id)
    return sim

# %% [markdown]
# *Note: The above has been formed in a similar way to sim_1, i.e, without tfidf and with stemming the tokens.This is because when we actually compare the recommendations given using different similarity matrices, we see that sim_1 gives us the best results. Thus later, what we do is that we combine both of sim_1 and sim_cat to get relevant and interesting recommendations. If sim_cat had been made using tdidf then the value of its elements would have been really small compared to sim_1's and it would have been a little difficult trying to make a similarity matrix which uses both of these to make recommendations.*

# %%
sim_cat = similarity_matrix_cat(df)
# Out:
# C:\Users\pansa.DESKTOP-2QTDA2J\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'formerli', 'forti', 'ha', 'henc', 'hereaft', 'herebi', 'hi', 'howev', 'hundr', 'inde', 'latterli', 'mani', 'meanwhil', 'moreov', 'mostli', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'seriou', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'thi', 'thu', 'togeth', 'twelv', 'twenti', 'veri', 'wa', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(

# %%
sim_cat.to_csv('../data_for_notebooks/internshala_recommendation_df_cat.csv', index = True)
